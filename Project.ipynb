# %%
import torch
from IPython.display import Image
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
import tensorflow as tf

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="XgC4KxFaTN29cH5YDQaa")
project = rf.workspace("dodge-eman-guerrero-17dlo").project("project-e4vdw")
dataset = project.version(14).download("yolov7")

# %%
# !git clone https://github.com/ultralytics/yolov5.git

# %%
physical_devices = tf.config.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], True)
print(os.getcwd())
# Out:
# C:\Users\7\Desktop\Python File\yolov5

# %%
# !python train.py --img 416 --batch 32 --epochs 15 --data data.yaml --weights yolov5s.pt --cache
# Out:
# ^C
# Command 'git fetch origin' timed out after 5 seconds
# train: weights=yolov5s.pt, cfg=, data=data.yaml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=15, batch_size=32, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# From https://github.com/ultralytics/yolov5
#    342fe05..443ef7f  master     -> origin/master
#    fa3c9bf..d371b16  exp13      -> origin/exp13
# fatal: cannot change to 'C:\Users\7\Desktop\Python': No such file or directory
# YOLOv5  2022-12-4 Python-3.10.7 torch-1.12.1+cpu CPU
#
# ...

# %%
Image(filename='runs/train/exp2/train_batch1.jpg', width=1000)

# %%
print(os.getcwd())
os.chdir("C:/Users/7/Desktop/Python File/")
# %cd yolov5
# Out:
# C:\Users\7\Desktop\Python File\yolov5
# C:\Users\7\Desktop\Python File\yolov5

# %%
# !python detect.py --source 0 --weights runs/train/exp2/weights/best.pt
# Out:
# PET 0.29
# PET
# PET 0.29
#
# PET 0.29
#
# PET 0.29
#
# PET 0.29
#
# PET 0.29
#
# PET 0.29
#
# PET 0.29
#
# PET 0.29
#
# PET 0.29
#
# PET 0.29
#
# PET 0.29
#
# PET 0.29
#
# PET 0.29
#
# PET 0.29
#
# PET 0.29
#
# PET 0.29
#
# PET 0.29
#
# PET 0.29
#
# PET 0.29
#
# PET 0.29
#
# PET 0.29
#
# PET 0.29
#
# PET 0.29
#
# PET 0.29
#
# PET 0.29
#
# PET 0.29
#
# PET 0.29
#
# LDPE 0.30
# LDPE
# LDPE 0.30
#
# LDPE 0.30
#
# LDPE 0.30
#
# LDPE 0.30
#
# LDPE 0.30
#
# LDPE 0.30
#
# LDPE 0.30
#
# LDPE 0.30
#
# LDPE 0.30
#
# LDPE 0.30
#
# LDPE 0.30
#
# LDPE 0.30
#
# LDPE 0.30
#
# LDPE 0.30
#
# LDPE 0.30
#
# LDPE 0.30
#
# LDPE 0.30
#
# LDPE 0.30
#
# LDPE 0.30
#
# LDPE 0.30
#
# LDPE 0.30
#
# LDPE 0.45
# LDPE
# LDPE 0.38
# LDPE
# LDPE 0.37
# LDPE
# LDPE 0.54
# LDPE
# PET 0.45
# PET
# PET 0.27
# PET
# PET 0.28
# PET
# PET 0.28
#
# PET 0.28
#
# PET 0.51
# PET
# PET 0.43
# PET
# PET 0.44
# PET
# PET 0.44
#
# LDPE 0.30
# LDPE
# PET 0.45
# PET
# PET 0.60
# PETs
# PET 0.34
# PET
# PET 0.56
# PETPP
# PET 0.60
# ...

# %%
pip install pyserial
# Out:
# ...
#      ---------------------------------------- 90.6/90.6 kB 1.0 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import serial

def sendData():
    data = "OFF"
    arduinoData = serial.Serial('com3', 115200)
    data = data+'\r'
    arduinoData.write(data.encode())
sendData()
